# %% [markdown]
# # PDF Importing 📄
# In this notebook we will focus on importing PDF files into the Vector database.
# We will focus on impoting documents from local storage, Google Drive and Microsoft OneDrive.
#
# ## Importing from local storage

# %%
from unstructured.partition.auto import partition
# Out:
# /Users/ben/GitHub/paginx/.venv/lib/python3.12/site-packages/pypandoc/pandoc_download.py:61: SyntaxWarning: invalid escape sequence '\.'
#   regex = re.compile(r"/jgm/pandoc/releases/download/.*(?:"+processor_architecture+"|x86|mac).*\.(?:msi|deb|pkg)")

# %%
elements = partition("./documents/grondwetNL.pdf")

# %%
print("\n\n".join([str(el) for el in elements]))
# Out:
# De Belgische Grondwet
#
# maart 2021
#
# 2
#
# Dienst Juridische Zaken en Parlementaire Documentatie van de Kamer van volksvertegenwoordigers D/2021/4686/01
#
# Deze brochure bevat de tekst van de gecoördineerde Grondwet van 17 februari
#
# 1994, aangevuld met de volgende grondwetsherzieningen:
#
# Titel artikel 5 artikel 7bis artikel 8 artikel 10 artikel 11bis
#
# Ibis
#
# artikel 12 artikel 14bis artikel 22bis
#
# artikel 22ter artikel 23 artikel 39bis artikel 39ter artikel 41
#
# artikel 43 artikel 44 artikel 46 artikel 56 artikel 57 artikel 59 artikel 63 artikel 64 artikel 65 artikel 66 artikel 67 artikel 68 artikel 69 artikel 70 artikel 71
#
# artikel 72 artikel 74 artikel 75 artikel 76 artikel 77 artikel 78
#
# ...
